# %%
import roboticstoolbox as rtb

puma = rtb.models.DH.Puma560()

# %%
print(puma)
# Out:
# DHRobot: Puma 560 (by Unimation), 6 joints (RRRRRR), dynamics, geometry, standard DH parameters
# ┌─────┬────────┬────────┬────────┬─────────┬────────┐
# │ θⱼ  │   dⱼ   │   aⱼ   │   ⍺ⱼ   │   q⁻    │   q⁺   │
# ├─────┼────────┼────────┼────────┼─────────┼────────┤
# │  q1 │ 0.6718 │      0 │  90.0° │ -160.0° │ 160.0° │
# │  q2 │      0 │ 0.4318 │   0.0° │ -110.0° │ 110.0° │
# │  q3 │   0.15 │ 0.0203 │ -90.0° │ -135.0° │ 135.0° │
# │  q4 │ 0.4318 │      0 │  90.0° │ -266.0° │ 266.0° │
# │  q5 │      0 │      0 │ -90.0° │ -100.0° │ 100.0° │
# │  q6 │      0 │      0 │   0.0° │ -266.0° │ 266.0° │
# └─────┴────────┴────────┴────────┴─────────┴────────┘
#
# ┌──┬──┐
# └──┴──┘
#
# ┌──────┬─────┬──────┬───────┬─────┬──────┬─────┐
# │ name │ q0  │ q1   │ q2    │ q3  │ q4   │ q5  │
# ├──────┼─────┼──────┼───────┼─────┼──────┼─────┤
# │   qr │  0° │  90° │ -90°  │  0° │  0°  │  0° │
# │   qz │  0° │  0°  │  0°   │  0° │  0°  │  0° │
# │   qn │  0° │  45° │  180° │  0° │  45° │  0° │
# │   qs │  0° │  0°  │ -90°  │  0° │  0°  │  0° │
# └──────┴─────┴──────┴───────┴─────┴──────┴─────┘

# %%
Fk = puma.fkine(puma.qz)

print(Fk)
# Out:
#    1         0         0         0.4521
#    0         1         0        -0.15
#    0         0         1         1.104
#    0         0         0         1

# %%
puma.teach(puma.qz)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 puma.teach(puma.qz)
#
# File c:\Users\Tal I\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboticstoolbox\robot\BaseRobot.py:2830, in BaseRobot.teach(self, q, block, limits, vellipse, fellipse, backend)
#    2819 env.launch("Teach " + self.name, limits=limits)
#    2820 env.add(
#    2821     self,
#    2822     readonly=True,
#    (...)
#    2827     # name=name,
#    2828 )
# -> 2830 env._add_teach_panel(self, q)
#    2832 if vellipse:
#    2833     vell = self.vellipse(q, centre="ee", scale=0.5)
#
# File c:\Users\Tal I\AppData\Local\Programs\Python\Python312\Lib\site-packages\roboticstoolbox\backends\PyPlot\PyPlot.py:474, in PyPlot._add_teach_panel(self, robot, q)
#     471 def _add_teach_panel(self, robot, q):
#     473     if _isnotebook():
# --> 474         raise RuntimeError("cannot use teach panel under Jupyter")
#     476     fig = self.fig
#     478     # Add text to the plots
#
# RuntimeError: cannot use teach panel under Jupyter

# %%
from spatialmath import SE3

Tep = SE3.Trans(0.6, -0.3, 0.1) * SE3.OA([0, 1, 0], [0, 0, -1])
sol = puma.ik_LM(Tep)         # solve IK
print(sol)

# (array([ 0.20592815,  0.86609481, -0.79473206, -1.68254794,  0.74872915,
#         2.21764746, -0.10255606]), 1, 114, 7, 2.890164057230228e-07)

q_pickup = sol[0]

print(puma.fkine(q_pickup))    # FK shows that desired end-effector pose was achieved
# Out:
# (array([2.52066302, 0.18567593, 1.57829868, 2.73380231, 1.05299277,
#        0.86215015]), 0, 3100, 101, 5.6694460602033995e-05)
#    0.6894   -0.07873   0.7201    0.08997
#    0.2068    0.9741   -0.09144   0.1201
#   -0.6943    0.2119    0.6878    0.6886
#    0         0         0         1

# %%
qt = rtb.jtraj(puma.qr, q_pickup, 50)
puma.plot(qt.q, backend='pyplot', movie='puma.gif')
# Out:
# PyPlot3D backend, t = 2.499999999999999, scene:
#   robot: Text(0.0, 0.0, 'Puma 560')
